# %%
import pandas as pd
from category_encoders import TargetEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# %%
data_path = "./data/lot51_cleaned.csv"
df = pd.read_csv(data_path)
df.head(5)
# Out:
#                                                 name  price  \
# 0  Mens Jogging Bottoms Elasticated Trouser Jogge...  14.48
# 1  Men's 100% Cotton  Big Polka Dot Design Spread...  29.19
# 2  G-Unit Style heavy weigh Tank Top  Square Cut ...  15.89
# 3  Men's Fashion Oxford Faux  Leather Dress Shoes...  33.23
# 4  Women's Cute Caged Peep Toe Low High Platform ...  15.81
#
#                            brand   item_condition  shipping      located_in  \
# 0                 Crazy Girl Ltd    New with tags       1.0  United Kingdom
# 1           George/Fortino Landi    New with tags       1.0   United States
# 2                          Basix    New with tags       1.0   United States
# 3  Milano Moda & Alberto Fellini     New with box       1.0   United States
# 4                       Top Moda  New without box       1.0   United States
#
#    return_policy                                           category  \
# 0              1  Clothing, Shoes & Accessories/Men/Men's Clothi...
# 1              1  Clothing, Shoes & Accessories/Men/Men's Clothi...
# 2              1  Clothing, Shoes & Accessories/Men/Men's Clothi...
# 3              1  Clothing, Shoes & Accessories/Men/Men's Shoes/...
# 4              1  Clothing, Shoes & Accessories/Women/Women's Sh...
#
#    money_back  seller_item_sold  trending  price_boxcox  price_log
# 0           1          203000.0         1      3.447473   2.739549
# 1           1           49000.0         1      4.667444   3.407511
# 2           1          207000.0         1      3.600318   2.826722
# 3           1           49000.0         1      4.910672   3.533102
# 4           1          326000.0         0      3.591949   2.821974

# %%
df.shape
# Out:
# (31170, 13)

# %%
tfid = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfid.fit_transform(df['name'])
k_means = KMeans(n_clusters=50, random_state=0)
k_means.fit(tfidf_matrix)
df['name'] = k_means.labels_
df.head()
# Out:
# /Users/jaxxsulav/Projects/Loyalist/Sem2/Step/PriceProphet/env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    name  price                          brand   item_condition  shipping  \
# 0    11  14.48                 Crazy Girl Ltd    New with tags       1.0
# 1    16  29.19           George/Fortino Landi    New with tags       1.0
# 2    43  15.89                          Basix    New with tags       1.0
# 3    36  33.23  Milano Moda & Alberto Fellini     New with box       1.0
# 4    17  15.81                       Top Moda  New without box       1.0
#
#        located_in  return_policy  \
# 0  United Kingdom              1
# 1   United States              1
# 2   United States              1
# 3   United States              1
# 4   United States              1
#
#                                             category  money_back  \
# 0  Clothing, Shoes & Accessories/Men/Men's Clothi...           1
# 1  Clothing, Shoes & Accessories/Men/Men's Clothi...           1
# 2  Clothing, Shoes & Accessories/Men/Men's Clothi...           1
# 3  Clothing, Shoes & Accessories/Men/Men's Shoes/...           1
# 4  Clothing, Shoes & Accessories/Women/Women's Sh...           1
#
#    seller_item_sold  trending  price_boxcox  price_log
# 0          203000.0         1      3.447473   2.739549
# 1           49000.0         1      4.667444   3.407511
# 2          207000.0         1      3.600318   2.826722
# 3           49000.0         1      4.910672   3.533102
# 4          326000.0         0      3.591949   2.821974

# %% [markdown]
# #### Dealing with Category

# %%
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])
df.head()
# Out:
#    name  price                          brand   item_condition  shipping  \
# 0    11  14.48                 Crazy Girl Ltd    New with tags       1.0
# 1    16  29.19           George/Fortino Landi    New with tags       1.0
# 2    43  15.89                          Basix    New with tags       1.0
# 3    36  33.23  Milano Moda & Alberto Fellini     New with box       1.0
# 4    17  15.81                       Top Moda  New without box       1.0
#
#        located_in  return_policy  category  money_back  seller_item_sold  \
# 0  United Kingdom              1        26           1          203000.0
# 1   United States              1        73           1           49000.0
# 2   United States              1        86           1          207000.0
# 3   United States              1       187           1           49000.0
# 4   United States              1       395           1          326000.0
#
#    trending  price_boxcox  price_log
# 0         1      3.447473   2.739549
# 1         1      4.667444   3.407511
# 2         1      3.600318   2.826722
# 3         1      4.910672   3.533102
# 4         0      3.591949   2.821974

# %% [markdown]
# ### Target Encoder for item_condition

# %%
encoder = TargetEncoder()

encoder.fit(df['item_condition'], df['price_log'])
df['item_condition'] = encoder.transform(df['item_condition'])

encoder.fit(df['brand'], df['price_log'])
df['brand'] = encoder.transform(df['brand'])

encoder.fit(df['located_in'], df['price_log'])
df['located_in'] = encoder.transform(df['located_in'])

# df.head()

# %%
df.dtypes
# Out:
# name                  int32
# price               float64
# brand               float64
# item_condition      float64
# shipping            float64
# located_in          float64
# return_policy         int64
# category              int64
# money_back            int64
# seller_item_sold    float64
# trending              int64
# price_boxcox        float64
# price_log           float64
# dtype: object

# %%
df.to_csv("./data/lot51_vectorized.csv", index=False)
